# %%
import matplotlib.pyplot as plt

plt.plot([0, 1, 2], [1, 4, 0]) # 앞에가 x 좌표, 뒤에가 y 좌표
plt.show()

# %%
plt.plot([0, 2, 5], [1, 4, 0]) # 앞에가 x 좌표, 뒤에가 y 좌표
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 50)
y = x**2

plt.plot(x, y)
plt.show()
