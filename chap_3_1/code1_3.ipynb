# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(dpi=200)

fig.set_facecolor('0.7')
ax.set_facecolor('0.5')
ax.set_title('Test Title', color='w')
ax.plot([0, 1], [0, 1], color='w')
plt.show()
